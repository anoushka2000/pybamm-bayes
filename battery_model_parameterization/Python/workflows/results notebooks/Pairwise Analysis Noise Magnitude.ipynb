# %%
# %load_ext autoreload
# %autoreload 2

import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

from battery_model_parameterization.Python import analysis

# %% [markdown]
# ***
#
# ### $$ε = 0.005 V $$

# %%
logs_dir_name= "De__Ds_p__200722_1758"
analysis.view_data(logs_dir_name)

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %% [markdown]
# ***
#
# ### $$ε = 0.025 V $$

# %%
logs_dir_name= "noise__De__Ds_p__230822_2251"

# %%
analysis.view_data(logs_dir_name)

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %%
analysis.pairwise(logs_dir_name)

# %% [markdown]
# ***
#
# ### $$ε = 0.05 V $$

# %%
logs_dir_name= "noise__De__Ds_p__230822_2252"
analysis.view_data(logs_dir_name)

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %%
analysis.pairwise(logs_dir_name)
