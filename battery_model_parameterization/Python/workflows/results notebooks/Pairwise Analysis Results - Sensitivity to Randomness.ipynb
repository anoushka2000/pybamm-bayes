# %%
# %load_ext autoreload

import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

from battery_model_parameterization.Python import analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## How does random noise impact parameter identifiability?
# Random noise is added to the data being used to identify parameters. Does different shape of noise (same average magnitude) lead to different convergence rates (all else remaining the same)?

# %%
logs_directories = ["De__Ds_p__210722_1556", "De__Ds_p__200722_1758"]

# %%
# %autoreload 2

analysis.compare_chain_convergence(logs_directories)

# %%
logs_directories = ["rate_1C__De__j0_n__240822_1221", "rate_1C__De__j0_n__240822_1251"]

# %%
analysis.compare_chain_convergence(logs_directories)
