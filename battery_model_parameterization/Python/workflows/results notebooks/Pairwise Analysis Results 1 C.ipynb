# %%
# %load_ext autoreload
# %autoreload 2

import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

from battery_model_parameterization.Python import analysis

# %% [markdown]
# ***
#
# ### $$D_e\;\:j_0,_n $$

# %%
logs_dir_name= "rate_1C__De__j0_n__240822_1221"

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %%
analysis.pairwise(logs_dir_name)

# %% [markdown]
# ***
#
# ### $$D_e\;\:j_0,_p $$

# %%
logs_dir_name= "De__j0_p__210722_1629"

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %%
analysis.pairwise(logs_dir_name)
