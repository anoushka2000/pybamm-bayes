# %%
# %load_ext autoreload
# %autoreload 2

import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

from battery_model_parameterization.Python import analysis

# %% [markdown]
# ***
#
# ### 3 Parameters

# %%
logs_dir_name= "multi_4__Ds_p__De__j0_n__250822_1241"
analysis.view_data(logs_dir_name)

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %%
analysis.pairwise(logs_dir_name)

# %% [markdown]
# ***
#
# ### 4 Parameters

# %%
logs_dir_name= "multi_4__Ds_p__De__j0_n__j0_p__250822_1241"

# %%
analysis.view_data(logs_dir_name)

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %%
analysis.pairwise(logs_dir_name)

# %% [markdown]
# ***
#
# ### 5 Parameters

# %%
logs_dir_name= "multi_5__Ds_n__Ds_p__De__j0_n__j0_p__250822_1241"
analysis.view_data(logs_dir_name)

# %%
analysis.plot_chain_convergence(logs_dir_name)

# %%
analysis.pairwise(logs_dir_name)
